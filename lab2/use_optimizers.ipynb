# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from SGDRegressor import BaseOptimizer, SGDRegressor
from optimizer import Momentum, Nesterov
import numpy as np
import pandas as pd

# %%
X = pd.read_csv("X.csv").to_numpy()[:, 1:]
y = pd.read_csv("y.csv").to_numpy()[:, 1]

# %%
optimizer = Momentum(0.9, 1e-4)
sgd = SGDRegressor(optimizer=optimizer)
sgd.fit(X, y)
# Out:
# array([[ 1.12161781, -1.79205837,  0.04363625]])

# %%
optimizer = Nesterov(0.9, 1e-4)
sgd = SGDRegressor(optimizer=optimizer)
sgd.fit(X, y)
# Out:
# array([[ 1.1286499 , -1.79262052,  0.06513941]])
